# %% [markdown]
# <a href="https://colab.research.google.com/github/Gwynbl31dd/BaseNodeServer/blob/master/XOR_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# XOR plot

# %%
import numpy as np;
import matplotlib.pyplot as plt;

# %%
x = np.random.rand(100,2);
y = np.random.rand(100,2);
#y = np.zeros(100);
#y[:50] = 1;
np.logical_xor(x,y)  
plt.scatter(x[:,0],y[:,1],c=a[:,1]);
